# %% [markdown]
# `Mark down Clean cheat Reference`
#
# ###### Mark Down Example 1
# <div class="alert alert-success alertsuccess" style="margin-top: 20px">
#     [Tip:] <code>print()</code> is a function. You passed the string <code>'Hello, Python!'</code> as an argument to instruct Python on what to print.
#     [Tip:] To execute the Python code in the code cell below, click on the cell to select it and press <kbd>Shift</kbd> + <kbd>Enter</kbd>.
# </div>
#
# ###### Mark Down Example 2
# ***
# `1. Markdown with in line code and keyboard button and htlm box format or check below`
# <div class="alert alert-success alertsuccess" style="margin-top: 20px"> Sample HTML box with some style </div>
#
# [Tip:] `print()` is a function. You passed the string `'Hello, Python!'` as an argument to instruct Python to print.
# [Tip:] To execute the Python code in the code cell below, click on the cell to select it and press <kbd>Shift</kbd> + <kbd>Enter</kbd>.
#
# `2. For Headers you can use single # up to six # and multiple dash/* for underline check below`
# # My Header
# Header1
# =======
# ### Header3
# ***
# ###### Header6
# ---
# `3. Block quotes can be nested, and can also contain other formatting.To create a block quote, start a line with greater than > followed by an optional space. check below`
# > *Hi, I am Dharmesh Patel*\
# > __do you know me?__
#
# `4. Emphasis: To make text bold or italic, wrap with asterisks * or underscores _. For a line break, add either a backslash \ or two blank spaces or <br> at the end of the line.`
#
# [Tip:] To avoid creating bold or italic, place a backslash in front such as `\* or \_.` <br>
# [Tip:] For bold text through use `**Dharmesh Patel** or __Dharmesh Patel__` Check __Dharmesh Patel__
# [Tip:] For Italic text through use `*Dharmesh Patel* ` Check -- *__Dharmesh Patel__*
# [Tip:] For strike through use `~~ such as abc ~~ ` ~~such as abc~~\
# [Tip:] To create a block quote, start a line with greater than > followed by an optional space.\
# [Tip:] To create Horizontal lines: Use three asterisks: `***`\
# [Tip:] To color text Use this code: `<font color=blue|red|green|pink|yellow>Text</font>`<font color=red>It'sRed!</font>
#
# `5. Unordered lists can use either asterisks *, plus +, or hyphens - as list markers. Ordered lists use numbers followed by period . or right parentheses ). Nested Lists, To nest one list within another, indent each item in the sublist by four spaces. You can also nest other elements like paragraphs, block quotes or code blocks. Check below Numbering `
#
# ---
# 1. Stick to a sleep schedule
# 3. Create a bedtime ritual
# 2. Get comfortable
#     1. Manage stress
#      - No of Planned Leaves in Month
#      + No. of Effective Working Days in Month
#      * Working Days
#     3. Check now
#      + Flour
#             - Cheese
#             * Tomatoes
# ---
# <kbd>6. Images and Links</kbd>
#
# `Links can be either in line with the text, or placed at the bottom of the text as references. Link text is enclosed by square brackets [], and for in line links, the link URL is enclosed by parentheses (). Images are almost identical to links, but an image starts with an exclamation point !.
# `
# 1. The [University of Rwanda](http://www.ur.ac.rw "University") was formed in 2013 through the merger of Rwanda’s seven public institutions of higher education.
# 2. The University of Rwanda <http://www.ur.ac.rw> was formed in 2013 through the merger of Rwanda’s seven public institutions of higher education.
# 3. [Click hear for Google Homepage](https://www.google.com "Takes you to Google")
# 4. My Linkedin Profile: [Dharmesh Patel](https://www.linkedin.com/in/dharmesh-patel-46361134 "Linkedin")
# 5. You can click on link defined once with multiple reference for "Hurricane" below:\
# [Hurricane][1] Erika was the strongest and longest-lasting tropical cyclone in the 1997 Atlantic [hurricane][1] season.
# [1]:https://goo.gl/YEEHP0
# 6. Just logo![](https://commonmark.org/help/images/favicon.png)
# 7. Logo with with reference and hover ![logo][2]
# [2]: https://commonmark.org/help/images/favicon.png "Creative Commons licensed"
# 8. Image with size  <img src="https://upload.wikimedia.org/wikipedia/commons/a/a1/Laxmi_Vilas_Palace%2C_Vadodara.jpg" width=80 length=80/>
# ---
#
# `7 To create in line code, wrap with back ticks, for code block, either indent each line by 4 spaces, or place 3 back ticks on a line above and below the code block.`
#
# ---
#
# `Who ate the most donuts this week?`
#
#     Jeff  15
#     Sam   11
#     Robin  6
# ----
#
# `A loop in Java Script:`
#
# ```
# A loop in Java Script:
# var i;
# for (i=0; i<5; i++) {
#   console.log(i);
# }
# ```
# ---
# ```
# Colors: Use this code <font color=blue|red|green|pink|yellow>Text</font>, Not all markdown code works within a font tag, so review your colored text carefully!
#
# Geometric shapes: Use this code with a decimal or hex reference number from here: UTF-8 Geometric shapes &#reference_number;
# Internal links: To link to a section, use this code: [section title](#section-title) For the text in the parentheses, replace spaces and special characters with a hyphen. Make sure to test all the links!
#
# Alternatively, you can add an ID for a section right above the section title. Use this code: <a id="section_ID"></a> Make sure that the section_ID is unique within the notebook.
#
# Use this code for the link and make sure to test all the links! [section title](#section_ID)
# External links: Use this code and test all links! [link text](http://url)
# ```
#
# ---
